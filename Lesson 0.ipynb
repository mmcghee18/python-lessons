# %% [markdown]
# ## Hi! 👋🏽
# This is just a test to make sure you can access the Jupyter Notebooks.
#
# The notebooks consist of cells (like this rectangle here) - text cells and code cells. Try running the code cell below by 1) clicking it and 2) pressing Shift+Enter.
#
# It should print 'hello world!' under the cell.

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# That's it! 🎉
